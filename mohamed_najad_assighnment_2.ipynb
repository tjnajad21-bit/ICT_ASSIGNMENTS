# %% [markdown]
# # Q1

# %%
for num in range(1,101):
    if num % 3 == 0 and num % 5 == 0:
        print('FizzzBuzz')
    elif num % 3 == 0:
        print('Fizz')
    elif num % 5 == 0:
        print('Buzz')
    else:
        print(num)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# FizzzBuzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# FizzzBuzz
# 46
# 47
# Fizz
# 49
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# 56
# Fizz
# 58
# 59
# FizzzBuzz
# 61
# 62
# Fizz
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# Buzz
# 71
# Fizz
# 73
# 74
# FizzzBuzz
# 76
# 77
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# Fizz
# Buzz
# 86
# Fizz
# 88
# 89
# FizzzBuzz
# 91
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# 98
# Fizz
# Buzz

# %% [markdown]
# # Q2

# %%
units = int(input('enter units consumed:'))
bill = 0
if units <= 100:
    bill = units * 5
elif units <= 200:
    bill = (100 *5) + (units -100) * 7
else:
    bill = (100 * 5) + (100 * 7) + (units - 200) * 10
print('total bill amount:  ₹',bill)
# Out:
# enter units consumed:1560
# total bill amount:  ₹ 14800

# %% [markdown]
# # Q3

# %%
for i in range(1,6):
    print('*' * i)
# Out:
# *
# **
# ***
# ****
# *****

# %% [markdown]
# # Q4

# %%
text = input('enter num or string to be checked: ')
text = str(text)
if text == text[::-1]:
    print('given num/string is palindrome')
else:
    print('given num/string is NOT palindome')
# Out:
# enter num or string to be checked: 1
# given num/string is palindrome
